# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Drinkig Water Potability

# %% [markdown]
# # Problem Statement- Classify the water quality whether it is potable or not based on the features provided.

# %% [markdown]
# # Read Data

# %%
credit2=pd.read_csv(r"C:\Users\Lenovo\Downloads\water_potability.csv")
credit2
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
credit2.shape
# Out:
# (3276, 10)

# %%
#Checking missing value
credit2.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
#Treating Missing Value With Mean
credit2.ph=credit2.ph.fillna(credit2.ph.mean())
credit2.Sulfate=credit2.Sulfate.fillna(credit2.Sulfate.mean())
credit2.Trihalomethanes=credit2.Trihalomethanes.fillna(credit2.Trihalomethanes.mean())

# %%
credit2.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
#Checking Dtypes
credit2.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %%
#checking skewness
credit2.skew()
# Out:
# ph                 0.027796
# Hardness          -0.039342
# Solids             0.621634
# Chloramines       -0.012098
# Sulfate           -0.041184
# Conductivity       0.264490
# Organic_carbon     0.025533
# Trihalomethanes   -0.085161
# Turbidity         -0.007817
# Potability         0.450784
# dtype: float64

# %% [markdown]
# # Visualization

# %%
fig = plt.figure(figsize=(5,5))
ax=sns.countplot(data=credit2, x='Potability')
plt.title("Potability Feature", size=20, weight='bold')
# Out:
# Text(0.5, 1.0, 'Potability Feature')

# %% [markdown]
# There is imbalance in the Target variable.

# %%
credit2.hist(figsize=(14,14))
plt.show()

# %% [markdown]
# All The Independent Feature are Normally Distributed

# %%
credit1=credit2.corr()
credit1
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.075833 -0.081884    -0.031811  0.014403
# Hardness         0.075833  1.000000 -0.046899    -0.030054 -0.092766
# Solids          -0.081884 -0.046899  1.000000    -0.070148 -0.149840
# Chloramines     -0.031811 -0.030054 -0.070148     1.000000  0.023791
# Sulfate          0.014403 -0.092766 -0.149840     0.023791  1.000000
# Conductivity     0.017192 -0.023915  0.013831    -0.020486 -0.014059
# Organic_carbon   0.040061  0.003610  0.010242    -0.012653  0.026909
# Trihalomethanes  0.002994 -0.012690 -0.008875     0.016627 -0.025605
# Turbidity       -0.036222 -0.014449  0.019546     0.002363 -0.009790
# Potability      -0.003287 -0.013837  0.033743     0.023779 -0.020619
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.017192        0.040061         0.002994  -0.036222
# ...

# %%
plt.figure(figsize=(15,10))
heatmap=sns.heatmap(credit1,linewidth=1,annot=True,cmap=plt.cm.Blues)
plt.title("Dataplot")
plt.show()

# %% [markdown]
# # BASE MODEL

# %%
x=credit2.iloc[:,0:-1]
y=credit2.iloc[:,-1]

# %%
x.head()
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Potability, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_tr,x_te,y_tr,y_te=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
x_tr.shape,x_te.shape,y_tr.shape,y_te.shape
# Out:
# ((2620, 9), (656, 9), (2620,), (656,))

# %% [markdown]
# # Logistic Regrssion

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()

# %%
lg.fit(x_tr,y_tr)
# Out:
# LogisticRegression()

# %%
lg_pred=lg.predict(x_te)
#lg_pred

# %%
from sklearn.metrics import confusion_matrix

# %%
m1=confusion_matrix(lg_pred,y_te)
m1
# Out:
# array([[400, 256],
#        [  0,   0]], dtype=int64)

# %%
ac1=m1.diagonal().sum()/m1.sum()*100
ac1
# Out:
# 60.97560975609756

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(lg_pred,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.61      0.76       656
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.61       656
#    macro avg       0.50      0.30      0.38       656
# weighted avg       1.00      0.61      0.76       656

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(x_tr,y_tr)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred=dt.predict(x_te)
#dt_pred

# %%
m2=confusion_matrix(dt_pred,y_te)
m2
# Out:
# array([[266, 136],
#        [134, 120]], dtype=int64)

# %%
dt_acc=m2.diagonal().sum()/m2.sum()*100
dt_acc
# Out:
# 58.84146341463414

# %%
print(classification_report(dt_pred,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.66      0.66       402
#            1       0.47      0.47      0.47       254
#
#     accuracy                           0.59       656
#    macro avg       0.57      0.57      0.57       656
# weighted avg       0.59      0.59      0.59       656

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x_tr,y_tr)
# Out:
# RandomForestClassifier()

# %%
rf_pred=rf.predict(x_te)
#rf_pred

# %%
m3=confusion_matrix(rf_pred,y_te)
m3
# Out:
# array([[359, 177],
#        [ 41,  79]], dtype=int64)

# %%
acc_rf=m3.diagonal().sum()/m3.sum()*100
acc_rf
# Out:
# 66.76829268292683

# %%
print(classification_report(rf_pred,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.67      0.77       536
#            1       0.31      0.66      0.42       120
#
#     accuracy                           0.67       656
#    macro avg       0.60      0.66      0.59       656
# weighted avg       0.79      0.67      0.70       656

# %% [markdown]
# # Boosting

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
ad=AdaBoostClassifier(DecisionTreeClassifier(),n_estimators=5)

# %%
ad.fit(x_tr,y_tr)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=5)

# %%
ad_pred=ad.predict(x_te)
#ad_pred

# %%
m4=confusion_matrix(ad_pred,y_te)
m4
# Out:
# array([[263, 134],
#        [137, 122]], dtype=int64)

# %%
acc_ad=m4.diagonal().sum()/m4.sum()*100
acc_ad
# Out:
# 58.6890243902439

# %%
print(classification_report(ad_pred,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66       397
#            1       0.48      0.47      0.47       259
#
#     accuracy                           0.59       656
#    macro avg       0.57      0.57      0.57       656
# weighted avg       0.59      0.59      0.59       656

# %% [markdown]
# # XG Boost

# %%
from xgboost import XGBClassifier
xg=XGBClassifier()

# %%
xg.fit(x_tr,y_tr)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
xg_pred=xg.predict(x_te)
#xg_pred

# %%
m5=confusion_matrix(xg_pred,y_te)
m5
# Out:
# array([[316, 155],
#        [ 84, 101]], dtype=int64)

# %%
acc_ad=m5.diagonal().sum()/m5.sum()*100
acc_ad
# Out:
# 63.5670731707317

# %%
print(classification_report(xg_pred,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.67      0.73       471
#            1       0.39      0.55      0.46       185
#
#     accuracy                           0.64       656
#    macro avg       0.59      0.61      0.59       656
# weighted avg       0.68      0.64      0.65       656

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier(n_neighbors=17)

# %%
kn.fit(x_tr,y_tr)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
kn_pred=kn.predict(x_te)
#kn_pred

# %%
m6=confusion_matrix(kn_pred,y_te)
m6
# Out:
# array([[346, 212],
#        [ 54,  44]], dtype=int64)

# %%
acc_kn=m6.diagonal().sum()/m6.sum()*100
acc_kn
# Out:
# 59.45121951219512

# %%
print(classification_report(kn_pred,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.62      0.72       558
#            1       0.17      0.45      0.25        98
#
#     accuracy                           0.59       656
#    macro avg       0.52      0.53      0.49       656
# weighted avg       0.76      0.59      0.65       656

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svc=SVC()

# %%
svc.fit(x_tr,y_tr)
# Out:
# SVC()

# %%
svc_pred=kn.predict(x_te)
#svc_pred

# %%
m7=confusion_matrix(svc_pred,y_te)
m7
# Out:
# array([[346, 212],
#        [ 54,  44]], dtype=int64)

# %%
acc_svc=m7.diagonal().sum()/m7.sum()*100
acc_svc
# Out:
# 59.45121951219512

# %%
print(classification_report(svc_pred,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.62      0.72       558
#            1       0.17      0.45      0.25        98
#
#     accuracy                           0.59       656
#    macro avg       0.52      0.53      0.49       656
# weighted avg       0.76      0.59      0.65       656

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()

# %%
nb.fit(x_tr,y_tr)
# Out:
# MultinomialNB()

# %%
nb_pred=nb.predict(x_te)
#nb_pred

# %%
m8=confusion_matrix(nb_pred,y_te)
m8
# Out:
# array([[248, 133],
#        [152, 123]], dtype=int64)

# %%
acc_nb=m8.diagonal().sum()/m8.sum()*100
acc_nb
# Out:
# 56.55487804878049

# %%
print(classification_report(nb_pred,y_te))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.64       381
#            1       0.48      0.45      0.46       275
#
#     accuracy                           0.57       656
#    macro avg       0.55      0.55      0.55       656
# weighted avg       0.56      0.57      0.56       656

# %%
# FROM THE ABOVE BASE MODEL ACCURACY OF
#1.LOGISTIC REGRESSION=60.97%
#2.DECISION TREE=58.84%
#3.RANDOM FOREST=66.76%
#4.AdaBOOST=58.68%
#5.XGBOOST=63.56%
#6.KNN=59.45%
#7.SVM=59.45%
#8.NAIVE BAYES=56.55%
#RANDOM FOREST HAS HIGH ACCURACY

# %% [markdown]
# # Class Imbalance Technique

# %% [markdown]
# # Balance the Data with Random Oversampling Technique

# %%
credit2.Potability.value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
c_0,c_1=credit2["Potability"].value_counts()
c_0,c_1
# Out:
# (1998, 1278)

# %%
df_0=credit2[credit2["Potability"]==0]
df_1=credit2[credit2["Potability"]==1]

# %%
df_0.shape,df_1.shape
# Out:
# ((1998, 10), (1278, 10))

# %%
class_1over=df_1.sample(c_0,replace=True)
#class_1over

# %%
credit=pd.concat([class_1over,df_0],axis=0)
#credit

# %%
credit.Potability.value_counts()
# Out:
# 1    1998
# 0    1998
# Name: Potability, dtype: int64

# %%
credit.shape
# Out:
# (3996, 10)

# %%
fig = plt.figure(figsize=(5,5))
ax=sns.countplot(data=credit, x='Potability')
plt.title("Potability Feature", size=20, weight='bold')
# Out:
# Text(0.5, 1.0, 'Potability Feature')

# %%
credit.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
credit.boxplot(figsize=(40,10))
# Out:
# <AxesSubplot: >

# %%
credit.boxplot(column="ph")
# Out:
# <AxesSubplot: >

# %%
#credit.ph.hist(bins=50)
sns.distplot(credit["ph"])
# Out:
# <AxesSubplot: xlabel='ph', ylabel='Density'>

# %%
credit.ph.describe()
# Out:
# count    3996.000000
# mean        7.070038
# std         1.458441
# min         0.000000
# 25%         6.277463
# 50%         7.080795
# 75%         7.859644
# max        14.000000
# Name: ph, dtype: float64

# %%
ub=credit["ph"].mean()+3*credit["ph"].std()
lb=credit["ph"].mean()-3*credit["ph"].std()
print(lb,ub)
# Out:
# 2.694715409698394 11.445361412319848

# %%
credit.loc[credit["ph"]>11.44,"ph"]=11.44
credit.loc[credit["ph"]<2.69,"ph"]=2.69

# %%
credit.boxplot(column="ph")
# Out:
# <AxesSubplot: >

# %%
#credit.ph.hist(bins=50)
sns.distplot(credit["ph"])
# Out:
# <AxesSubplot: xlabel='ph', ylabel='Density'>

# %%
credit.boxplot(column="Hardness")
# Out:
# <AxesSubplot: >

# %%
#credit.Hardness.hist(bins=50)
sns.distplot(credit["Hardness"])
# Out:
# <AxesSubplot: xlabel='Hardness', ylabel='Density'>

# %%
credit["Hardness"].describe()
# Out:
# count    3996.000000
# mean      196.296395
# std        33.484789
# min        47.432000
# 25%       176.808661
# 50%       196.696937
# 75%       217.368447
# max       323.124000
# Name: Hardness, dtype: float64

# %%
ub=credit["Hardness"].mean()+3*credit["Hardness"].std()
lb=credit["Hardness"].mean()-3*credit["Hardness"].std()
print(lb,ub)
# Out:
# 95.84202752789918 296.7507618560718

# %%
credit.loc[credit["Hardness"]>296.75,"Hardness"]=296.75
credit.loc[credit["Hardness"]<95.84,"Hardness"]=95.84

# %%
credit.boxplot(column="Hardness")
# Out:
# <AxesSubplot: >

# %%
#credit.Hardness.hist(bins=50)
sns.distplot(credit["Hardness"])
# Out:
# <AxesSubplot: xlabel='Hardness', ylabel='Density'>

# %%
credit.boxplot(column="Solids")
# Out:
# <AxesSubplot: >

# %%
#credit.Solids.hist(bins=50)
sns.distplot(credit["Solids"])
# Out:
# <AxesSubplot: xlabel='Solids', ylabel='Density'>

# %%
credit.Solids.describe()
# Out:
# count     3996.000000
# mean     21948.399976
# std       8892.549008
# min        320.942611
# 25%      15489.233432
# 50%      20682.731742
# 75%      27270.381387
# max      61227.196008
# Name: Solids, dtype: float64

# %%
iqr1=credit.Solids.quantile(0.75)-credit.Solids.quantile(0.25)
iqr1
# Out:
# 11781.147954712314

# %%
u1=credit["Solids"].quantile(0.75)+3*iqr1
l1=credit["Solids"].quantile(0.25)-3*iqr1
print(u1,l1)
# Out:
# 62613.82525078718 -19854.21043219902

# %%
credit.loc[credit["Solids"]>62613.82,"Solids"]=62613.82

# %%
credit.boxplot(column="Solids")
# Out:
# <AxesSubplot: >

# %%
#credit.Solids.hist(bins=50)
sns.distplot(credit["Solids"])
# Out:
# <AxesSubplot: xlabel='Solids', ylabel='Density'>

# %%
credit.boxplot(column="Chloramines")
# Out:
# <AxesSubplot: >

# %%
#credit.Chloramines.hist(bins=50)
sns.distplot(credit["Chloramines"])
# Out:
# <AxesSubplot: xlabel='Chloramines', ylabel='Density'>

# %%
credit["Chloramines"].describe()
# Out:
# count    3996.000000
# mean        7.120497
# std         1.592025
# min         0.352000
# 25%         6.130757
# 50%         7.123966
# 75%         8.104498
# max        13.127000
# Name: Chloramines, dtype: float64

# %%
ub=credit["Chloramines"].mean()+3*credit["Chloramines"].std()
lb=credit["Chloramines"].mean()-3*credit["Chloramines"].std()
print(lb,ub)
# Out:
# 2.3444232451158724 11.89657165265395

# %%
credit.loc[credit["Chloramines"]>11.89,"Chloramines"]=11.89
credit.loc[credit["Chloramines"]<2.34,"Chloramines"]=2.34

# %%
credit.boxplot(column="Chloramines")
# Out:
# <AxesSubplot: >

# %%
#credit.Chloramines.hist(bins=50)
sns.distplot(credit["Chloramines"])
# Out:
# <AxesSubplot: xlabel='Chloramines', ylabel='Density'>

# %%
credit.boxplot(column="Sulfate")
# Out:
# <AxesSubplot: >

# %%
#credit.Sulfate.hist(bins=50)
sns.distplot(credit["Sulfate"])
# Out:
# <AxesSubplot: xlabel='Sulfate', ylabel='Density'>

# %%
credit["Sulfate"].describe()
# Out:
# count    3996.000000
# mean      333.698919
# std        36.908621
# min       129.000000
# 25%       316.517814
# 50%       333.775777
# 75%       350.592000
# max       481.030642
# Name: Sulfate, dtype: float64

# %%
ub=credit["Sulfate"].mean()+3*credit["Sulfate"].std()
lb=credit["Sulfate"].mean()-3*credit["Sulfate"].std()
print(lb,ub)
# Out:
# 222.9730548518657 444.42478221122593

# %%
credit.loc[credit["Sulfate"]>444.42,"Sulfate"]=444.42
credit.loc[credit["Sulfate"]<222.97,"Sulfate"]=222.97

# %%
credit.boxplot(column="Sulfate")
# Out:
# <AxesSubplot: >

# %%
#credit.Sulfate.hist(bins=50)
sns.distplot(credit["Sulfate"])
# Out:
# <AxesSubplot: xlabel='Sulfate', ylabel='Density'>

# %%
credit.boxplot(column="Conductivity")
# Out:
# <AxesSubplot: >

# %%
#credit.Conductivity.hist(bins=50)
sns.distplot(credit["Conductivity"])
# Out:
# <AxesSubplot: xlabel='Conductivity', ylabel='Density'>

# %%
credit["Conductivity"].describe()
# Out:
# count    3996.000000
# mean      427.661002
# std        79.530760
# min       181.483754
# 25%       368.804295
# 50%       423.990944
# 75%       483.679950
# max       753.342620
# Name: Conductivity, dtype: float64

# %%
ub=credit["Conductivity"].mean()+3*credit["Conductivity"].std()
lb=credit["Conductivity"].mean()-3*credit["Conductivity"].std()
print(lb,ub)
# Out:
# 189.06872266193147 666.2532806148324

# %%
credit.loc[credit["Conductivity"]>666.25,"Conductivity"]=666.25
credit.loc[credit["Conductivity"]<189.06,"Conductivity"]=189.06

# %%
credit.boxplot(column="Conductivity")
# Out:
# <AxesSubplot: >

# %%
#credit.Conductivity.hist(bins=50)
sns.distplot(credit["Conductivity"])
# Out:
# <AxesSubplot: xlabel='Conductivity', ylabel='Density'>

# %%
credit.boxplot(column="Organic_carbon")
# Out:
# <AxesSubplot: >

# %%
#credit.Organic_carbon.hist(bins=50)
sns.distplot(credit["Organic_carbon"])
# Out:
# <AxesSubplot: xlabel='Organic_carbon', ylabel='Density'>

# %%
credit["Organic_carbon"].describe()
# Out:
# count    3996.000000
# mean       14.185364
# std         3.292242
# min         2.200000
# 25%        11.996084
# 50%        14.118936
# 75%        16.358019
# max        28.300000
# Name: Organic_carbon, dtype: float64

# %%
ub=credit["Organic_carbon"].mean()+3*credit["Organic_carbon"].std()
lb=credit["Organic_carbon"].mean()-3*credit["Organic_carbon"].std()
print(lb,ub)
# Out:
# 4.308637116329066 24.06209094434879

# %%
credit.loc[credit["Organic_carbon"]>24.06,"Organic_carbon"]=24.06
credit.loc[credit["Organic_carbon"]<4.30,"Organic_carbon"]=4.30

# %%
credit.boxplot(column="Organic_carbon")
# Out:
# <AxesSubplot: >

# %%
#credit.Organic_carbon.hist(bins=50)
sns.distplot(credit["Organic_carbon"])
# Out:
# <AxesSubplot: xlabel='Organic_carbon', ylabel='Density'>

# %%
credit.boxplot(column="Trihalomethanes")
# Out:
# <AxesSubplot: >

# %%
#credit.Trihalomethanes.hist(bins=50)
sns.distplot(credit["Trihalomethanes"])
# Out:
# <AxesSubplot: xlabel='Trihalomethanes', ylabel='Density'>

# %%
credit["Trihalomethanes"].describe()
# Out:
# count    3996.000000
# mean       66.584562
# std        15.618366
# min         0.738000
# 25%        56.801321
# 50%        66.396293
# 75%        76.824752
# max       124.000000
# Name: Trihalomethanes, dtype: float64

# %%
ub=credit["Trihalomethanes"].mean()+3*credit["Trihalomethanes"].std()
lb=credit["Trihalomethanes"].mean()-3*credit["Trihalomethanes"].std()
print(lb,ub)
# Out:
# 19.729462913017493 113.43966079122765

# %%
credit.loc[credit["Trihalomethanes"]>113.43,"Trihalomethanes"]=113.43
credit.loc[credit["Trihalomethanes"]<19.72,"Trihalomethanes"]=19.72

# %%
credit.boxplot(column="Trihalomethanes")
# Out:
# <AxesSubplot: >

# %%
#credit.Trihalomethanes.hist(bins=50)
sns.distplot(credit["Trihalomethanes"])
# Out:
# <AxesSubplot: xlabel='Trihalomethanes', ylabel='Density'>

# %%
credit.boxplot(column="Turbidity")
# Out:
# <AxesSubplot: >

# %%
#credit.Turbidity.hist(bins=50)
sns.distplot(credit["Turbidity"])
# Out:
# <AxesSubplot: xlabel='Turbidity', ylabel='Density'>

# %%
credit["Turbidity"].describe()
# Out:
# count    3996.000000
# mean        3.975198
# std         0.776759
# min         1.450000
# 25%         3.442983
# 50%         3.968647
# 75%         4.510792
# max         6.739000
# Name: Turbidity, dtype: float64

# %%
ub=credit["Turbidity"].mean()+3*credit["Turbidity"].std()
lb=credit["Turbidity"].mean()-3*credit["Turbidity"].std()
print(lb,ub)
# Out:
# 1.6449217132894423 6.305473720034168

# %%
credit.loc[credit["Turbidity"]>6.30,"Turbidity"]=6.30
credit.loc[credit["Turbidity"]<1.64,"Turbidity"]=1.64

# %%
credit.boxplot(column="Turbidity")
# Out:
# <AxesSubplot: >

# %%
#credit.Turbidity.hist(bins=50)
sns.distplot(credit["Turbidity"])
# Out:
# <AxesSubplot: xlabel='Turbidity', ylabel='Density'>

# %% [markdown]
# # Splitting The Balanced Data

# %%
xo=credit.iloc[:,0:-1]
yo=credit.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
n1ox_train,n1ox_test,n1oy_train,n1oy_test=train_test_split(xo,yo,test_size=0.2,random_state=100)

# %%
n1ox_train.shape,n1ox_test.shape,n1oy_train.shape,n1oy_test.shape
# Out:
# ((3196, 9), (800, 9), (3196,), (800,))

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()

# %%
lg.fit(n1ox_train,n1oy_train)
# Out:
# LogisticRegression()

# %%
lg_pno=lg.predict(n1ox_test)
#lg_pno

# %%
from sklearn.metrics import confusion_matrix

# %%
c_lgo=confusion_matrix(lg_pno,n1oy_test)
c_lgo
# Out:
# array([[226, 241],
#        [154, 179]], dtype=int64)

# %%
Acc_lgo=c_lgo.diagonal().sum()/c_lgo.sum()*100
Acc_lgo
# Out:
# 50.625

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(lg_pno,n1oy_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.48      0.53       467
#            1       0.43      0.54      0.48       333
#
#     accuracy                           0.51       800
#    macro avg       0.51      0.51      0.50       800
# weighted avg       0.52      0.51      0.51       800

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(n1ox_train,n1oy_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pno=dt.predict(n1ox_test)
#dt_pno

# %%
c_dto=confusion_matrix(lg_pno,n1oy_test)
c_dto
# Out:
# array([[226, 241],
#        [154, 179]], dtype=int64)

# %%
Acc_dto=c_dto.diagonal().sum()/c_dto.sum()*100
Acc_dto
# Out:
# 50.625

# %%
print(classification_report(dt_pno,n1oy_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.79      0.75       345
#            1       0.83      0.76      0.80       455
#
#     accuracy                           0.78       800
#    macro avg       0.77      0.78      0.77       800
# weighted avg       0.78      0.78      0.78       800

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(n1ox_train,n1oy_train)
# Out:
# RandomForestClassifier()

# %%
rf_pno=rf.predict(n1ox_test)
#rf_pno

# %%
c_rfo=confusion_matrix(rf_pno,n1oy_test)
c_rfo
# Out:
# array([[333,  77],
#        [ 47, 343]], dtype=int64)

# %%
Acc_rfo=c_rfo.diagonal().sum()/c_rfo.sum()*100
Acc_rfo
# Out:
# 84.5

# %%
print(classification_report(rf_pno,n1oy_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       410
#            1       0.82      0.88      0.85       390
#
#     accuracy                           0.84       800
#    macro avg       0.85      0.85      0.84       800
# weighted avg       0.85      0.84      0.84       800

# %% [markdown]
# # Boosting

# %% [markdown]
# # AdaBoost

# %%
ad.fit(n1ox_train,n1oy_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=5)

# %%
ad_pno=ad.predict(n1ox_test)
#ad_pno

# %%
c_ado=confusion_matrix(ad_pno,n1oy_test)
c_ado
# Out:
# array([[273,  75],
#        [107, 345]], dtype=int64)

# %%
Acc_ado=c_ado.diagonal().sum()/c_ado.sum()*100
Acc_ado
# Out:
# 77.25

# %%
print(classification_report(ad_pno,n1oy_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.78      0.75       348
#            1       0.82      0.76      0.79       452
#
#     accuracy                           0.77       800
#    macro avg       0.77      0.77      0.77       800
# weighted avg       0.78      0.77      0.77       800

# %% [markdown]
# # XGBoost

# %%
xg.fit(n1ox_train,n1oy_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
xg_pno=xg.predict(n1ox_test)
#xg_pno

# %%
c_xgo=confusion_matrix(xg_pno,n1oy_test)
c_xgo
# Out:
# array([[303,  76],
#        [ 77, 344]], dtype=int64)

# %%
Acc_xgo=c_xgo.diagonal().sum()/c_xgo.sum()*100
Acc_xgo
# Out:
# 80.875

# %%
print(classification_report(xg_pno,n1oy_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       379
#            1       0.82      0.82      0.82       421
#
#     accuracy                           0.81       800
#    macro avg       0.81      0.81      0.81       800
# weighted avg       0.81      0.81      0.81       800

# %% [markdown]
# # Support Vector Machine

# %%
svc.fit(n1ox_train,n1oy_train)
# Out:
# SVC()

# %%
svc_pno=svc.predict(n1ox_test)
#svc_pno

# %%
c_svco=confusion_matrix(svc_pno,n1oy_test)
c_svco
# Out:
# array([[311, 326],
#        [ 69,  94]], dtype=int64)

# %%
Acc_svco=c_svco.diagonal().sum()/c_svco.sum()*100
Acc_svco
# Out:
# 50.625

# %%
print(classification_report(svc_pno,n1oy_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.49      0.61       637
#            1       0.22      0.58      0.32       163
#
#     accuracy                           0.51       800
#    macro avg       0.52      0.53      0.47       800
# weighted avg       0.70      0.51      0.55       800

# %% [markdown]
# # Naive Bayes

# %%
nb.fit(n1ox_train,n1oy_train)
# Out:
# MultinomialNB()

# %%
nb_pno=nb.predict(n1ox_test)
#nb_pno

# %%
c_nbo=confusion_matrix(nb_pno,n1oy_test)
c_nbo
# Out:
# array([[188, 227],
#        [192, 193]], dtype=int64)

# %%
Acc_nbo=c_nbo.diagonal().sum()/c_nbo.sum()*100
Acc_nbo
# Out:
# 47.625

# %%
print(classification_report(nb_pno,n1oy_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.45      0.47       415
#            1       0.46      0.50      0.48       385
#
#     accuracy                           0.48       800
#    macro avg       0.48      0.48      0.48       800
# weighted avg       0.48      0.48      0.48       800

# %% [markdown]
# # KNN

# %%
kn.fit(n1ox_train,n1oy_train)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
kn_pno=kn.predict(n1ox_test)
#kn_pno

# %%
c_kno=confusion_matrix(kn_pno,n1oy_test)
c_kno
# Out:
# array([[231, 182],
#        [149, 238]], dtype=int64)

# %%
Acc_kno=c_kno.diagonal().sum()/c_kno.sum()*100
Acc_kno
# Out:
# 58.62500000000001

# %%
print(classification_report(kn_pno,n1oy_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.56      0.58       413
#            1       0.57      0.61      0.59       387
#
#     accuracy                           0.59       800
#    macro avg       0.59      0.59      0.59       800
# weighted avg       0.59      0.59      0.59       800

# %%
#  FROM THE ABOVE MODELS WHICH CREATED FROM BALANCED DATA WITH OUTLIER TREATMENT 
#           USING RANDOM OVERSAMPLING TECHNIQUE ACCURACY IS
#1.LOGISTIC REGRESSION=50.62%
#2.DECISION TREE=50.62%
#3.RANDOM FOREST=84.50%
#4.AdaBOOST=77.25%
#5.XGBOOST=80.87%
#6.KNN=58.62%
#7.SVM=50.62%
#8.NAIVE BAYES=47.62%
#RANDOM FOREST HAS HIGH ACCURACY

# %% [markdown]
# # After Treating Imbalance Problem With Help Of Random Oversampling Technique, Random Forest is Showing Good Accuracy as 84.00%
